# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = pd.read_excel('CSM_dataset.xlsx')

# %% [markdown]
# ##### A) Interpolation is a technique in Python used to estimate unknown data points between two known data points. Interpolation is mostly used to impute missing values in the dataframe or series while preprocessing data.
# ##### Linear Interpolation simply means to estimate a missing value by connecting dots in a straight line in increasing order. In short, It estimates the unknown value in the same increasing order from previous values.

# %%
ds.interpolate(method ='linear', limit_direction ='forward')
# Out:
#                       Movie  Year  Ratings  Genre      Gross       Budget  \
# 0                   13 Sins  2014      6.3      8       9130    4000000.0
# 1            22 Jump Street  2014      7.1      1  192000000   50000000.0
# 2            3 Days to Kill  2014      6.2      1   30700000   28000000.0
# 3    300: Rise of an Empire  2014      6.3      1  106000000  110000000.0
# 4         A Haunted House 2  2014      4.7      8   17300000    3500000.0
# ..                      ...   ...      ...    ...        ...          ...
# 226                Child 44  2015      6.4      4    1210000   50000000.0
# 227                   Aloha  2015      5.5     15   21000000   37000000.0
# 228     Unfinished Business  2015      5.4      8   10200000   35000000.0
# 229                War Room  2015      5.4      1   12300000    3000000.0
# 230             The Gallows  2015      4.4     15   22600000     100000.0
#
#      Screens  Sequel  Sentiment    Views  Likes  Dislikes  Comments  \
# ...

# %% [markdown]
# ##### A)correlation calculation between each two columns

# %%
print(ds.corr())
# Out:
#                          Year   Ratings     Genre     Gross    Budget  \
# Year                 1.000000 -0.001213 -0.026277  0.122672  0.098516
# Ratings             -0.001213  1.000000 -0.116735  0.342204  0.288157
# Genre               -0.026277 -0.116735  1.000000 -0.197009 -0.264286
# Gross                0.122672  0.342204 -0.197009  1.000000  0.719839
# Budget               0.098516  0.288157 -0.264286  0.719839  1.000000
# Screens              0.251472  0.057625 -0.145807  0.586447  0.595684
# Sequel               0.103996  0.105701 -0.224474  0.423711  0.464733
# Sentiment            0.229858  0.143182 -0.010831 -0.017100  0.033616
# Views                0.207959  0.011710 -0.032047  0.176363  0.114708
# Likes                0.084561  0.073824 -0.043544  0.110432  0.011701
# Dislikes             0.234496 -0.187422 -0.031730  0.161536  0.096888
# Comments             0.043037  0.015679 -0.099919  0.125960  0.090559
# ...

# %% [markdown]
# ##### show correlation plot between each two columns

# %%
pd.plotting.scatter_matrix(ds.loc[:,:],figsize = (40,30))
# Out:
# array([[<AxesSubplot:xlabel='Year', ylabel='Year'>,
#         <AxesSubplot:xlabel='Ratings', ylabel='Year'>,
#         <AxesSubplot:xlabel='Genre', ylabel='Year'>,
#         <AxesSubplot:xlabel='Gross', ylabel='Year'>,
#         <AxesSubplot:xlabel='Budget', ylabel='Year'>,
#         <AxesSubplot:xlabel='Screens', ylabel='Year'>,
#         <AxesSubplot:xlabel='Sequel', ylabel='Year'>,
#         <AxesSubplot:xlabel='Sentiment', ylabel='Year'>,
#         <AxesSubplot:xlabel='Views', ylabel='Year'>,
#         <AxesSubplot:xlabel='Likes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Dislikes', ylabel='Year'>,
#         <AxesSubplot:xlabel='Comments', ylabel='Year'>,
#         <AxesSubplot:xlabel='Aggregate Followers', ylabel='Year'>],
#        [<AxesSubplot:xlabel='Year', ylabel='Ratings'>,
#         <AxesSubplot:xlabel='Ratings', ylabel='Ratings'>,
#         <AxesSubplot:xlabel='Genre', ylabel='Ratings'>,
#         <AxesSubplot:xlabel='Gross', ylabel='Ratings'>,
# ...

# %% [markdown]
# ##### C) 'Year' and 'Sequel' feature are same for all the row  also view and (comments,dislike,like) has correlation and we can consider one of them.
